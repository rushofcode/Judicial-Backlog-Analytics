# %%
import pandas as pd

# %%
df = pd.read_csv("/content/row_cases.csv")
df.head()
# Out:
#    Unnamed: 0                          State/UT  \
# 0           0                             India
# 1           1  Andaman and Nicobar Islands (UT)
# 2           2                    Andhra Pradesh
# 3           3                 Arunachal Pradesh
# 4           4                             Assam
#
#    Budget per capita on judiciary (₹) (2020–21)  \
# 0                                           146
# 1                                           337
# 2                                           145
# 3                                           199
# 4                                            99
#
#    Population per High Court Judge (2022)  \
# 0                                 1765760
# 1                                 1833444
# 2                                 1765733
# 3                                 1681917
# 4                                 1681917
#
#    Population per Lower Court Judge (2022) Courthall shortfall (%) (2022)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    37 non-null     int64
#  1   State/UT                                      37 non-null     object
#  2   Budget per capita on judiciary (₹) (2020–21)  37 non-null     int64
#  3   Population per High Court Judge (2022)        37 non-null     int64
#  4   Population per Lower Court Judge (2022)       37 non-null     int64
#  5   Courthall shortfall (%) (2022)                36 non-null     object
#  6   Case clearance rate of High Court (2022)      37 non-null     int64
#  7   Case clearance rate of Lower Court (2022)     37 non-null     float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.4+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                      0
# State/UT                                        0
# Budget per capita on judiciary (₹) (2020–21)    0
# Population per High Court Judge (2022)          0
# Population per Lower Court Judge (2022)         0
# Courthall shortfall (%) (2022)                  1
# Case clearance rate of High Court (2022)        0
# Case clearance rate of Lower Court (2022)       0
# dtype: int64

# %%
df.shape
# Out:
# (37, 8)
